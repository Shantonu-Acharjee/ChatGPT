ENWJoG2Tjj3JWKwy3QmUWIrCGtZPb_rvZpw7AwuRwtZzUgKimf2Untg1o6cWxiqlLk6UfoUrrEOBDJ96wduBy2rc6vcH2bGKb3k0N0hs4Y3LE83PJ_05FS5_gJX-jrsv0P0LbyLo6BxUkJGIV3bkpVV_DmOEaxhSw1zmy-GDLedZLWlGYr4HwDDezUPidiz8K2luoF3OG9imfXLVLMvl8meZ17jx-xldBFV3Xa976EuTtq9ahcvgOF5fUY3_oeK8a-bOlKmcqa-bvJHRIU19bCrmWIYUku_mxz8zzJX7k6-HAv_joNqbXIYzWHzn09-qRlqoF_iNEHR7d3x3Y0AwxL9pT6Q_yEHwmqUNjfyW3tNpGfYawJOb-shZG7zVR3eayvp8CnwbOOUmyDMWseF0LKod5Za8wiC4r0s-QItVLNIBq85GC-W2iuPfFVeZvAQuYMtjuX8snevxbT1t81KEn_VnRcRVt9Z_Ml1oUQ9WGrfa2wAXbocDD7M6RDV8oFOaajmE_J7WHK4j-Kc6D67s5P57dezQT5TiMlN_v0ADlUJd_CA8wkIE71ZN0m6MX80TyU3A44euNcy65Deutzy2u1YggwzX5JWY7wB86ttBqKr7WB9b4Z7juusMX3MRqmJbnRj08WgR2SQOAT0hUQApNWa_gCA17iDV2vf3FXN2xDKeSiGuXUvzm80p876nnYk8XgkKC6pXF_gbaK_CNKPqkhdAXMUcwMlHJgNgQIoJ_GkFZpCs55jckbN7t_Ka_eEPGGj7n5Vc-vweCsGr-09xHctXzlMnnAu6B0H55kjPOmE5HOlJAQqBTOUJnxw8IYpjfu70J2hs6LnTxkWeM5Mve7y4I0Z98K0sD96WEIp97NGecM1bDJ7KsGbnWQEl_yRS9zALZb6-CFN7ZBqIEYYPl03xInR0wtXB_za-UhFZQwriDfDPy0mmjTtyld-e9FhxgwKnjiqTIRxv2Tk_fJbYdtiqf6O7Utb2L6SCtaB192hYsG5nBsot1WKODpU2a7H1sOzp0vLSimy7zovY6AUROTYgJGLbfjRGcAaWyvJB9YgpqQmq1agHsohya5ziQ3B8dyyYMR5Ybj8UvXrJUQNNBFBiy0UAIOzgukq74.e3kQyqBcu9yyTgDEJRvWBg'  # `__Secure-next-auth.session-token` cookie from https://chat.openai.com/chat
api = ChatGPT(session_token)  # auth with session token

# %%
# api2 = ChatGPT(email='example@domain.com', password='password')  # auth with email and password
# api3 = ChatGPT(session_token, conversation_id='some-random-uuid')  # specify a conversation id
# api4 = ChatGPT(session_token, proxy='http://proxy.example.com:8080')  # specify proxy

# %%
resp = api.send_message('Who are you')
print(resp['message'])
# Out:
# I am ChatGPT, a large language model developed by OpenAI. I am designed to respond to questions and engage in conversations with users. My purpose is to assist and provide information to the best of my knowledge and capabilities. How can I assist you today?

# %%
api.refresh_chat_page

# %%
api.refresh_chat_page()  # refresh the authorization token
api.reset_conversation()  # reset the conversation
